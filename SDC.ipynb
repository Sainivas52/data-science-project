# %% [markdown]
# <a href="https://colab.research.google.com/github/Sainivas52/data-science-project/blob/main/SDC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# define a dctinary containing employebdata
import pandas as pd
data1={'Name':['Jai','Princi','Gaurav','Anu'],
       'Age':[27,24,22,32],
       'Address':['Nagpur','Kanpur','Allahabad','Kannuaj'],
       'Qualification':['Msc','MA','MCA','Phd']}
data2={'Name':['Abhi','Ayushi','Dhiraj','Hitesh'],
       'Age':[17,14,12,52],
       'Address':['Nagpur','Kanpur','Allahabad','Kannuaj'],
       'Qualification':['Btech','B.A','B.Com','B.hons']}
df=pd.DataFrame(data1,index=[0,1,2,3])
df1=pd.DataFrame(data2,index=[4,5,6,7])
print(df,'\n\n',df1)
#using a.concat() method
frames=[df,df1]
res1=pd.concat(frames)
print(res1)
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3     Anu   32    Kannuaj           Phd
#
#       Name  Age    Address Qualification
# 4    Abhi   17     Nagpur         Btech
# 5  Ayushi   14     Kanpur           B.A
# 6  Dhiraj   12  Allahabad         B.Com
# 7  Hitesh   52    Kannuaj        B.hons
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3     Anu   32    Kannuaj           Phd
# 4    Abhi   17     Nagpur         Btech
# 5  Ayushi   14     Kanpur           B.A
# 6  Dhiraj   12  Allahabad         B.Com
# 7  Hitesh   52    Kannuaj        B.hons

# %%
import pandas as pd
data1={'Name':['Jai','Princi','Gaurav','Anu'],
       'Age':[27,24,22,32],
       'Address':['Nagpur','Kanpur','Allahabad','Kannuaj'],
       'Qualification':['Msc','MA','MCA','Phd']}
data2={'Name':['Abhi','Ayushi','Dhiraj','Hitesh'],
       'Age':[17,14,12,52],
       'Address':['Nagpur','Kanpur','Allahabad','Kannuaj'],
       'Qualification':['Btech','B.A','B.Com','B.hons']}
df=pd.DataFrame(data1,index=[0,1,2,3])
df1=pd.DataFrame(data2,index=[2,3,6,7])
print(df,'\n\n',df1)
res1=pd.concat([df,df1])
res1
res2=pd.concat([df,df1],axis=1,join='inner')
res2
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3     Anu   32    Kannuaj           Phd
#
#       Name  Age    Address Qualification
# 2    Abhi   17     Nagpur         Btech
# 3  Ayushi   14     Kanpur           B.A
# 6  Dhiraj   12  Allahabad         B.Com
# 7  Hitesh   52    Kannuaj        B.hons
#      Name  Age    Address Qualification    Name  Age Address Qualification
# 2  Gaurav   22  Allahabad           MCA    Abhi   17  Nagpur         Btech
# 3     Anu   32    Kannuaj           Phd  Ayushi   14  Kanpur           B.A

# %%
import pandas as pd
data1={'Name':['Jai','Princi','Gaurav','Anu'],
       'Age':[27,24,22,32],
       'Address':['Nagpur','Kanpur','Allahabad','Kannuaj'],
       'Qualification':['Msc','MA','MCA','Phd']}
data2={'Name':['Abhi','Ayushi','Dhiraj','Hitesh'],
       'Age':[17,14,12,52],
       'Address':['Nagpur','Kanpur','Allahabad','Kannuaj'],
       'Qualification':['Btech','B.A','B.Com','B.hons']}
df=pd.DataFrame(data1,index=[0,1,2,3])
df1=pd.DataFrame(data2,index=[2,3,6,7])
print(df,'\n\n',df1)
res2=pd.concat([df,df1],axis=1,ignore_index=True)
res2
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3     Anu   32    Kannuaj           Phd
#
#       Name  Age    Address Qualification
# 2    Abhi   17     Nagpur         Btech
# 3  Ayushi   14     Kanpur           B.A
# 6  Dhiraj   12  Allahabad         B.Com
# 7  Hitesh   52    Kannuaj        B.hons
#         0     1          2    3       4     5          6       7
# 0     Jai  27.0     Nagpur  Msc     NaN   NaN        NaN     NaN
# 1  Princi  24.0     Kanpur   MA     NaN   NaN        NaN     NaN
# 2  Gaurav  22.0  Allahabad  MCA    Abhi  17.0     Nagpur   Btech
# 3     Anu  32.0    Kannuaj  Phd  Ayushi  14.0     Kanpur     B.A
# 6     NaN   NaN        NaN  NaN  Dhiraj  12.0  Allahabad   B.Com
# 7     NaN   NaN        NaN  NaN  Hitesh  52.0    Kannuaj  B.hons

# %%
import pandas as pd
data1={'Key':['K0','K1','K2','K3'],
       'Key1':['K0','K1','K0','K1'],
       'Name':['Jai','Princi','Gaurav','Anuj'],
       'Age':[27,24,22,32],}
data2={'Key':['K0','K1','K2','K3'],
       'Key1':['K0','K0','K0','K0'],
       'Address':['Nagpur','Kanpur','Allahabad','Kannuaj'],
       'Qualification':['Btech','B.A','B.Com','B.hons']}
df=pd.DataFrame(data1)
df1=pd.DataFrame(data2)
print(df,"\n\n",df1)
res=pd.merge(df,df1,on=['Key','Key1'])
res
# Out:
#   Key Key1    Name  Age
# 0  K0   K0     Jai   27
# 1  K1   K1  Princi   24
# 2  K2   K0  Gaurav   22
# 3  K3   K1    Anuj   32
#
#    Key Key1    Address Qualification
# 0  K0   K0     Nagpur         Btech
# 1  K1   K0     Kanpur           B.A
# 2  K2   K0  Allahabad         B.Com
# 3  K3   K0    Kannuaj        B.hons
#   Key Key1    Name  Age    Address Qualification
# 0  K0   K0     Jai   27     Nagpur         Btech
# 1  K2   K0  Gaurav   22  Allahabad         B.Com

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
electricity=pd.read_csv("/content/energy.csv")
print(electricity)
# Out:
#           Date        State  Consumption
# 0   01-01-2024    Tamilnadu       347.25
# 1   02-01-2024      Manipur       605.12
# 2   03-01-2024    Telengana       444.63
# 3   04-01-2024  Pondicherry       974.54
# 4   05-01-2024    Tamilnadu       864.02
# ..         ...          ...          ...
# 95  05-04-2024       Kerala       587.30
# 96  06-04-2024           UP       726.21
# 97  07-04-2024       Andhra       305.70
# 98  08-04-2024       Sikkim       257.46
# 99  09-04-2024  Pondicherry       983.95
#
# [100 rows x 3 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
electricity=pd.read_csv("/content/energy.csv")
print(electricity)
print(electricity.shape)
print(electricity.head(5))
print(electricity.tail(4))
print(electricity.info())
print(electricity.describe)
# Out:
#           Date        State  Consumption
# 0   01-01-2024    Tamilnadu       347.25
# 1   02-01-2024      Manipur       605.12
# 2   03-01-2024    Telengana       444.63
# 3   04-01-2024  Pondicherry       974.54
# 4   05-01-2024    Tamilnadu       864.02
# ..         ...          ...          ...
# 95  05-04-2024       Kerala       587.30
# 96  06-04-2024           UP       726.21
# 97  07-04-2024       Andhra       305.70
# 98  08-04-2024       Sikkim       257.46
# 99  09-04-2024  Pondicherry       983.95
#
# [100 rows x 3 columns]
# (100, 3)
#          Date        State  Consumption
# 0  01-01-2024    Tamilnadu       347.25
# 1  02-01-2024      Manipur       605.12
# 2  03-01-2024    Telengana       444.63
# 3  04-01-2024  Pondicherry       974.54
# 4  05-01-2024    Tamilnadu       864.02
#           Date        State  Consumption
# 96  06-04-2024           UP       726.21
# 97  07-04-2024       Andhra       305.70
# 98  08-04-2024       Sikkim       257.46
# 99  09-04-2024  Pondicherry       983.95
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         100 non-null    object
#  1   State        100 non-null    object
#  2   Consumption  100 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 2.5+ KB
# None
# <bound method NDFrame.describe of           Date        State  Consumption
# 0   01-01-2024    Tamilnadu       347.25
# 1   02-01-2024      Manipur       605.12
# 2   03-01-2024    Telengana       444.63
# 3   04-01-2024  Pondicherry       974.54
# 4   05-01-2024    Tamilnadu       864.02
# ..         ...          ...          ...
# 95  05-04-2024       Kerala       587.30
# 96  06-04-2024           UP       726.21
# 97  07-04-2024       Andhra       305.70
# 98  08-04-2024       Sikkim       257.46
# 99  09-04-2024  Pondicherry       983.95
#
# [100 rows x 3 columns]>

# %%
print("Column Data")
print(electricity.columns)
print(electricity[electricity['State'].str.startswith("M")])
print(electricity[electricity['State'].str.endswith("a")])
rcb=electricity[electricity['State']=='Andhra']
print(len(rcb))
# Out:
# Column Data
# Index(['Date', 'State', 'Consumption'], dtype='object')
#           Date    State  Consumption
# 1   02-01-2024  Manipur       605.12
# 18  19-01-2024  Mizoram       643.98
# 21  22-01-2024  Manipur       948.57
# 22  23-01-2024  Manipur       638.98
# 37  07-02-2024  Manipur       682.92
# 41  11-02-2024  Manipur       248.19
# 44  14-02-2024  Mizoram       723.19
# 60  01-03-2024  Manipur       469.93
# 67  08-03-2024  Manipur       597.60
# 70  11-03-2024  Manipur       432.69
# 80  21-03-2024  Mizoram       726.23
#           Date      State  Consumption
# 2   03-01-2024  Telengana       444.63
# 5   06-01-2024    Tripura       749.56
# 6   07-01-2024  Telengana       312.39
# 7   08-01-2024  Telengana       330.46
# 9   10-01-2024    Tripura       739.60
# 10  11-01-2024     Andhra       199.80
# 11  12-01-2024  Karnataka       495.40
# 14  15-01-2024  Karnataka       527.83
# 19  20-01-2024     Odisha       585.86
# 20  21-01-2024     Kerala       282.76
# 23  24-01-2024    Tripura       725.31
# 25  26-01-2024     Andhra       661.92
# 27  28-01-2024    Tripura       194.94
# 36  06-02-2024  Karnataka       344.92
# 40  10-02-2024    Tripura       374.30
# 42  12-02-2024     Andhra       580.68
# 45  15-02-2024  Telengana       342.47
# 47  17-02-2024  Telengana       251.46
# 49  19-02-2024  Karnataka       602.29
# 51  21-02-2024     Odisha       158.40
# 55  25-02-2024  Karnataka       741.04
# 56  26-02-2024     Odisha       233.28
# 59  29-02-2024     Kerala       978.95
# 64  05-03-2024     Kerala       712.63
# 78  19-03-2024  Telengana       235.65
# 79  20-03-2024    Tripura       557.38
# 82  23-03-2024     Andhra       393.36
# 83  24-03-2024     Andhra       298.22
# 86  27-03-2024     Odisha       413.80
# 93  03-04-2024  Karnataka       761.69
# 95  05-04-2024     Kerala       587.30
# 97  07-04-2024     Andhra       305.70
# 6

# %%
print("Column Data")
print(electricity.columns)
print(electricity[electricity['State'].str.startswith("M")])
print(electricity[electricity['State'].str.endswith("a")])
rcb=electricity[electricity['State']=='Manipur']
print(len(rcb))
# Out:
# Column Data
# Index(['Date', 'State', 'Consumption'], dtype='object')
#           Date    State  Consumption
# 1   02-01-2024  Manipur       605.12
# 18  19-01-2024  Mizoram       643.98
# 21  22-01-2024  Manipur       948.57
# 22  23-01-2024  Manipur       638.98
# 37  07-02-2024  Manipur       682.92
# 41  11-02-2024  Manipur       248.19
# 44  14-02-2024  Mizoram       723.19
# 60  01-03-2024  Manipur       469.93
# 67  08-03-2024  Manipur       597.60
# 70  11-03-2024  Manipur       432.69
# 80  21-03-2024  Mizoram       726.23
#           Date      State  Consumption
# 2   03-01-2024  Telengana       444.63
# 5   06-01-2024    Tripura       749.56
# 6   07-01-2024  Telengana       312.39
# 7   08-01-2024  Telengana       330.46
# 9   10-01-2024    Tripura       739.60
# 10  11-01-2024     Andhra       199.80
# 11  12-01-2024  Karnataka       495.40
# 14  15-01-2024  Karnataka       527.83
# 19  20-01-2024     Odisha       585.86
# 20  21-01-2024     Kerala       282.76
# 23  24-01-2024    Tripura       725.31
# 25  26-01-2024     Andhra       661.92
# 27  28-01-2024    Tripura       194.94
# 36  06-02-2024  Karnataka       344.92
# 40  10-02-2024    Tripura       374.30
# 42  12-02-2024     Andhra       580.68
# 45  15-02-2024  Telengana       342.47
# 47  17-02-2024  Telengana       251.46
# 49  19-02-2024  Karnataka       602.29
# 51  21-02-2024     Odisha       158.40
# 55  25-02-2024  Karnataka       741.04
# 56  26-02-2024     Odisha       233.28
# 59  29-02-2024     Kerala       978.95
# 64  05-03-2024     Kerala       712.63
# 78  19-03-2024  Telengana       235.65
# 79  20-03-2024    Tripura       557.38
# 82  23-03-2024     Andhra       393.36
# 83  24-03-2024     Andhra       298.22
# 86  27-03-2024     Odisha       413.80
# 93  03-04-2024  Karnataka       761.69
# 95  05-04-2024     Kerala       587.30
# 97  07-04-2024     Andhra       305.70
# 8

# %%
#print max unit for Andhra
print("Column Data")
print(electricity.columns)
print(electricity[electricity['State'].str.startswith("M")])
print(electricity[electricity['State'].str.endswith("a")])
rcb=electricity[electricity['State']=='Andhra']
print(len(rcb))
# Out:
# Column Data
# Index(['Date', 'State', 'Consumption'], dtype='object')
#           Date    State  Consumption
# 1   02-01-2024  Manipur       605.12
# 18  19-01-2024  Mizoram       643.98
# 21  22-01-2024  Manipur       948.57
# 22  23-01-2024  Manipur       638.98
# 37  07-02-2024  Manipur       682.92
# 41  11-02-2024  Manipur       248.19
# 44  14-02-2024  Mizoram       723.19
# 60  01-03-2024  Manipur       469.93
# 67  08-03-2024  Manipur       597.60
# 70  11-03-2024  Manipur       432.69
# 80  21-03-2024  Mizoram       726.23
#           Date      State  Consumption
# 2   03-01-2024  Telengana       444.63
# 5   06-01-2024    Tripura       749.56
# 6   07-01-2024  Telengana       312.39
# 7   08-01-2024  Telengana       330.46
# 9   10-01-2024    Tripura       739.60
# 10  11-01-2024     Andhra       199.80
# 11  12-01-2024  Karnataka       495.40
# 14  15-01-2024  Karnataka       527.83
# 19  20-01-2024     Odisha       585.86
# 20  21-01-2024     Kerala       282.76
# 23  24-01-2024    Tripura       725.31
# 25  26-01-2024     Andhra       661.92
# 27  28-01-2024    Tripura       194.94
# 36  06-02-2024  Karnataka       344.92
# 40  10-02-2024    Tripura       374.30
# 42  12-02-2024     Andhra       580.68
# 45  15-02-2024  Telengana       342.47
# 47  17-02-2024  Telengana       251.46
# 49  19-02-2024  Karnataka       602.29
# 51  21-02-2024     Odisha       158.40
# 55  25-02-2024  Karnataka       741.04
# 56  26-02-2024     Odisha       233.28
# 59  29-02-2024     Kerala       978.95
# 64  05-03-2024     Kerala       712.63
# 78  19-03-2024  Telengana       235.65
# 79  20-03-2024    Tripura       557.38
# 82  23-03-2024     Andhra       393.36
# 83  24-03-2024     Andhra       298.22
# 86  27-03-2024     Odisha       413.80
# 93  03-04-2024  Karnataka       761.69
# 95  05-04-2024     Kerala       587.30
# 97  07-04-2024     Andhra       305.70
# 6

# %%
state1_data=electricity[electricity['State']=='Andhra']
print("Andhra Data")
print(state1_data)
state2_data=electricity[electricity['State']=='Karnataka']
print("Karnataka Data")
print(state2_data)
state3_data=electricity[electricity['State']=='Telangana']
print("Telangana Data")
print(state3_data)
state4_data=electricity[electricity['State']=='Kerala']
fig, axes=plt.subplots(2)
axes[0].plot(state1_data['Date'],state1_data['Consumption'])
axes[1].plot(state2_data['Date'],state2_data['Consumption'])
plt.show()
# Out:
# Andhra Data
#           Date   State  Consumption
# 10  11-01-2024  Andhra       199.80
# 25  26-01-2024  Andhra       661.92
# 42  12-02-2024  Andhra       580.68
# 82  23-03-2024  Andhra       393.36
# 83  24-03-2024  Andhra       298.22
# 97  07-04-2024  Andhra       305.70
# Karnataka Data
#           Date      State  Consumption
# 11  12-01-2024  Karnataka       495.40
# 14  15-01-2024  Karnataka       527.83
# 36  06-02-2024  Karnataka       344.92
# 49  19-02-2024  Karnataka       602.29
# 55  25-02-2024  Karnataka       741.04
# 93  03-04-2024  Karnataka       761.69
# Telangana Data
# Empty DataFrame
# Columns: [Date, State, Consumption]
# Index: []

# %%
#bar chat
fig, axes=plt.subplots(2)
axes[0].bar(state3_data['Date'],state3_data['Consumption'])
axes[1].bar(state4_data['Date'],state4_data['Consumption'])
plt.show()

# %%
fig2,axes2=plt.subplots(2)
state1='UP'
state2='Kerala'
state3="Mizoram"
state4='Delhi'
labels=[state1,state2]
state1_data=electricity[electricity['State']==state1]['Consumption'].sum()
state2_data=electricity[electricity['State']==state2]['Consumption'].sum()
